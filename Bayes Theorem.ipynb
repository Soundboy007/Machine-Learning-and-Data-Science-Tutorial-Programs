# %%
import os
import io
import numpy
from pandas import DataFrame
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.naive_bayes import MultinomialNB

def readFiles(path):
    for root,dirnames,filenames in os.walk(path):
        for filename in filenames:
            path=os.path.join(root,filename)
            inBody=False
            lines=[]
            f=io.open(path,'r',encoding='latin1')
            for line in f:
                if inBody:
                    lines.append(line)
                elif line=='\n':
                    inBody=True
            f.close()
            message='\n'.join(lines)
            yield path,message
def dataFrameFromDirectory(path,classification):
    rows=[]
    index=[]
    for filename,message in readFiles(path):
        rows.append({'message':message,'class':classification})
        index.append(filename)
    return DataFrame(rows,index=index)
data=DataFrame({'message':[],'class':[]})
data=data.append(dataFrameFromDirectory('/Users/mohitpandrangi/Desktop/Data Science and Machine Learning with Python/DataScience-Python3/emails/spam','spam'))
data=data.append(dataFrameFromDirectory('/Users/mohitpandrangi/Desktop/Data Science and Machine Learning with Python/DataScience-Python3/emails/ham','ham'))

# %%
data
# Out:
#                                                    class  \
# /Users/mohitpandrangi/Desktop/Data Science and ...  spam
# /Users/mohitpandrangi/Desktop/Data Science and ...  spam
# /Users/mohitpandrangi/Desktop/Data Science and ...  spam
# /Users/mohitpandrangi/Desktop/Data Science and ...  spam
# /Users/mohitpandrangi/Desktop/Data Science and ...  spam
# /Users/mohitpandrangi/Desktop/Data Science and ...  spam
# /Users/mohitpandrangi/Desktop/Data Science and ...  spam
# /Users/mohitpandrangi/Desktop/Data Science and ...  spam
# /Users/mohitpandrangi/Desktop/Data Science and ...  spam
# /Users/mohitpandrangi/Desktop/Data Science and ...  spam
# /Users/mohitpandrangi/Desktop/Data Science and ...  spam
# /Users/mohitpandrangi/Desktop/Data Science and ...  spam
# /Users/mohitpandrangi/Desktop/Data Science and ...  spam
# /Users/mohitpandrangi/Desktop/Data Science and ...  spam
# /Users/mohitpandrangi/Desktop/Data Science and ...  spam
# ...

# %%
vectorizer=CountVectorizer()
counts=vectorizer.fit_transform(data['message'].values)
classifier=MultinomialNB()
targets=data['class'].values
classifier.fit(counts,targets)
# Out:
# MultinomialNB(alpha=1.0, class_prior=None, fit_prior=True)

# %%
examples=['Free Viagra now!!!','Hi Whats up?','CONGRATULATIONS! YOU WON $10,0000','Meeting on Monday','Are you Free?']
example_counts=vectorizer.transform(examples)
predictions=classifier.predict(example_counts)
predictions
# Out:
# array(['spam', 'ham', 'ham', 'ham', 'ham'], dtype='<U4')
